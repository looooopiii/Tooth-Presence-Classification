# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_excel('STL_Label_2025-05-06_IPI.xlsx', header=None)

# %%
df.head(7)
# Out:
#                                0   \
# 0                    STL-Labeling
# 1                      Version V1
# 2             2024-10-21 00:00:00
# 3                            File
# 4  142595_2023-12-07 UpperJawScan
# 5  190250_2023-12-14 LowerJawScan
# 6  046375_2024-09-17 LowerJawScan
#
#                                               1    2    3    4    5   \
# 0                                            NaN  NaN  NaN  NaN  NaN
# 1                                            NaN  NaN  NaN  NaN  NaN
# 2  Dental Status: Tooth Presence (0=no / 1=yes)   NaN  NaN  NaN  NaN
# 3                                             18   17   16   15   14
# 4                                              0    1    1    0    1
# 5                                            NaN  NaN  NaN  NaN  NaN
# 6                                            NaN  NaN  NaN  NaN  NaN
#
#                                     6    7    8    9   ...   25  \
# 0                                  NaN  NaN  NaN  NaN  ...  NaN
# 1                                  NaN  NaN  NaN  NaN  ...  NaN
# 2  Pathology-1: Carious Lesion (2=yes)  NaN  NaN  NaN  ...  NaN
# 3                                   13   12   11   21  ...   41
# 4                                    1  1,2    1  1,2  ...  NaN
# 5                                  NaN  NaN  NaN  NaN  ...    1
# 6                                  NaN  NaN  NaN  NaN  ...    1
#
#                               26   27     28   29   30   31   32  \
# 0                            NaN  NaN    NaN  NaN  NaN  NaN  NaN
# 1                            NaN  NaN    NaN  NaN  NaN  NaN  NaN
# 2  Prosthetics-3: Pontic (6=yes)  NaN    NaN  NaN  NaN  NaN  NaN
# 3                             42   43     44   45   46   47   48
# 4                            NaN  NaN    NaN  NaN  NaN  NaN  NaN
# 5                              1    1    1,4    0  1,4    0    0
# 6                              1  1.2  1,2,4  1.4    0    0    0
#
#                     33        34
# 0                  NaN       NaN
# 1                  NaN       NaN
# 2                  NaN       NaN
# 3     Date of labeling      File
# 4  2024-10-21 00:00:00  only STL
# 5  2024-10-21 00:00:00  only STL
# 6  2024-11-05 00:00:00       NaN
#
# [7 rows x 35 columns]

# %%
#df.iloc[3][0] = 'Filename'

# %%
# Use row 3 as columns
new_header = df.iloc[3].tolist()  # convert to list to avoid weird index name
df.columns = new_header

# Drop first four rows (0 to 3)
df = df.drop([0, 1, 2, 3])

# Reset index
df = df.reset_index(drop=True)

# %%
df
# Out:
#                                File   18   17    16   15   14   13   12   11  \
# 0    142595_2023-12-07 UpperJawScan    0    1     1    0    1    1  1,2    1
# 1    190250_2023-12-14 LowerJawScan  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 2    046375_2024-09-17 LowerJawScan  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 3    184824_2024-09-27 LowerJawScan  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 4    184824_2024-09-27 UpperJawScan    0    0  1 ,5  1.5  1.5  1.5  1.6  1.6
# ..                              ...  ...  ...   ...  ...  ...  ...  ...  ...
# 185  466662-2024-09-24 UpperJawScan    0    0     1    1    1    1    1    1
# 186  467830-2024-11-04 LowerJawScan  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 187  467830-2024-11-04 UpperJawScan    0  1.4   1.4  1.4  1.4    1    1    1
# 188       469239-01-14 LowerJawScan  NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 189       469239-01-14 UpperJawScan    0  1.5     0    0  1.4  1.5  1.6  1.6
#
#       21  ...   41   42   43     44     45     46     47   48  \
# 0    1,2  ...  NaN  NaN  NaN    NaN    NaN    NaN    NaN  NaN
# 1    NaN  ...    1    1    1    1,4      0    1,4      0    0
# 2    NaN  ...    1    1  1.2  1,2,4    1.4      0      0    0
# 3    NaN  ...    1  1.5  1.5    1.5    1.5    1.5      0    0
# 4    1.5  ...  NaN  NaN  NaN    NaN    NaN    NaN    NaN  NaN
# ..   ...  ...  ...  ...  ...    ...    ...    ...    ...  ...
# 185    1  ...  NaN  NaN  NaN    NaN    NaN    NaN    NaN  NaN
# 186  NaN  ...    1    1    1  1,3,4  1,3,4  1,3,4  1,3,4    0
# 187    1  ...  NaN  NaN  NaN    NaN    NaN    NaN    NaN  NaN
# 188  NaN  ...    1    1    1      1    1.5    1.6    1.5  1.5
# 189  1.5  ...  NaN  NaN  NaN    NaN    NaN    NaN    NaN  NaN
#
#         Date of labeling      File
# 0    2024-10-21 00:00:00  only STL
# 1    2024-10-21 00:00:00  only STL
# 2    2024-11-05 00:00:00       NaN
# 3    2024-11-05 00:00:00       NaN
# 4    2024-11-05 00:00:00       NaN
# ..                   ...       ...
# 185  2025-05-06 00:00:00       NaN
# 186  2025-05-06 00:00:00       NaN
# 187  2025-05-06 00:00:00       NaN
# 188  2025-05-06 00:00:00       NaN
# 189  2025-05-06 00:00:00       NaN
#
# [190 rows x 35 columns]

# %%
cols = df.columns.tolist()
cols[0] = "filename"     # first column
cols[-1] = "filetype"    # last column
df.columns = cols

# %%
df = df.fillna(0)
# Out:
# /tmp/ipykernel_804529/3475559988.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(0)

# %%
df
# Out:
#                            filename   18   17    16   15   14   13   12   11  \
# 0    142595_2023-12-07 UpperJawScan  0.0    1     1    0    1    1  1,2    1
# 1    190250_2023-12-14 LowerJawScan  0.0    0     0    0    0    0    0    0
# 2    046375_2024-09-17 LowerJawScan  0.0    0     0    0    0    0    0    0
# 3    184824_2024-09-27 LowerJawScan  0.0    0     0    0    0    0    0    0
# 4    184824_2024-09-27 UpperJawScan  0.0    0  1 ,5  1.5  1.5  1.5  1.6  1.6
# ..                              ...  ...  ...   ...  ...  ...  ...  ...  ...
# 185  466662-2024-09-24 UpperJawScan  0.0    0     1    1    1    1    1    1
# 186  467830-2024-11-04 LowerJawScan  0.0    0     0    0    0    0    0    0
# 187  467830-2024-11-04 UpperJawScan  0.0  1.4   1.4  1.4  1.4    1    1    1
# 188       469239-01-14 LowerJawScan  0.0    0     0    0    0    0    0    0
# 189       469239-01-14 UpperJawScan  0.0  1.5     0    0  1.4  1.5  1.6  1.6
#
#       21  ... 41   42   43     44     45     46     47   48 Date of labeling  \
# 0    1,2  ...  0    0    0      0      0      0      0    0       2024-10-21
# 1      0  ...  1    1    1    1,4      0    1,4      0    0       2024-10-21
# 2      0  ...  1    1  1.2  1,2,4    1.4      0      0    0       2024-11-05
# 3      0  ...  1  1.5  1.5    1.5    1.5    1.5      0    0       2024-11-05
# 4    1.5  ...  0    0    0      0      0      0      0    0       2024-11-05
# ..   ...  ... ..  ...  ...    ...    ...    ...    ...  ...              ...
# 185    1  ...  0    0    0      0      0      0      0    0       2025-05-06
# 186    0  ...  1    1    1  1,3,4  1,3,4  1,3,4  1,3,4    0       2025-05-06
# 187    1  ...  0    0    0      0      0      0      0    0       2025-05-06
# 188    0  ...  1    1    1      1    1.5    1.6    1.5  1.5       2025-05-06
# 189  1.5  ...  0    0    0      0      0      0      0    0       2025-05-06
#
#      filetype
# 0    only STL
# 1    only STL
# 2           0
# 3           0
# 4           0
# ..        ...
# 185         0
# 186         0
# 187         0
# 188         0
# 189         0
#
# [190 rows x 35 columns]

# %%
# for upper jaw
cols_to_process = [18, 17, 16, 15, 14, 13, 12, 11, 21, 22, 23, 24, 25, 26, 27, 28]
def to_binary(val):
    # Convert val to string and strip spaces
    val_str = str(val).strip()
    # If the whole string is '0' or '0.0', consider zero, else 1
    if val_str == '0' or val_str == '0.0' or val_str == 0:
        return 0
    else:
        return 1

df[cols_to_process] = df[cols_to_process].applymap(to_binary).astype(int)
# Out:
# /tmp/ipykernel_804529/1659882397.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[cols_to_process] = df[cols_to_process].applymap(to_binary).astype(int)

# %%
# for lower jaw
cols_to_process = [38,37,36,35,34,33,32,31,41,42,43,44,45,46,47,48]
def to_binary(val):
    # Convert val to string and strip spaces
    val_str = str(val).strip()
    # If the whole string is '0' or '0.0', consider zero, else 1
    if val_str == '0' or val_str == '0.0' or val_str == 0:
        return 0
    else:
        return 1

df[cols_to_process] = df[cols_to_process].applymap(to_binary).astype(int)  # Example to check the type conversion of a specific cell
# Out:
# /tmp/ipykernel_804529/2505657599.py:12: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[cols_to_process] = df[cols_to_process].applymap(to_binary).astype(int)  # Example to check the type conversion of a specific cell

# %%
df.head(7)
# Out:
#                          filename  18  17  16  15  14  13  12  11  21  ...  \
# 0  142595_2023-12-07 UpperJawScan   0   1   1   0   1   1   1   1   1  ...
# 1  190250_2023-12-14 LowerJawScan   0   0   0   0   0   0   0   0   0  ...
# 2  046375_2024-09-17 LowerJawScan   0   0   0   0   0   0   0   0   0  ...
# 3  184824_2024-09-27 LowerJawScan   0   0   0   0   0   0   0   0   0  ...
# 4  184824_2024-09-27 UpperJawScan   0   0   1   1   1   1   1   1   1  ...
# 5  186908_2024-10-21 LowerJawScan   0   0   0   0   0   0   0   0   0  ...
# 6  186908_2024-10-21 UpperJawScan   0   1   1   1   1   1   1   1   1  ...
#
#    41  42  43  44  45  46  47  48  Date of labeling  filetype
# 0   0   0   0   0   0   0   0   0        2024-10-21  only STL
# 1   1   1   1   1   0   1   0   0        2024-10-21  only STL
# 2   1   1   1   1   1   0   0   0        2024-11-05         0
# 3   1   1   1   1   1   1   0   0        2024-11-05         0
# 4   0   0   0   0   0   0   0   0        2024-11-05         0
# 5   1   1   1   1   1   1   1   0        2024-11-05         0
# 6   0   0   0   0   0   0   0   0        2024-11-05         0
#
# [7 rows x 35 columns]

# %%
df.to_csv("/home/user/tbrighton/blender-scripts/Testing/label1.csv", index=False)
print("\nSaved labeled test image data to label1.csv")
# Out:
# Saved labeled test image data to label1.csv

# %%
df.loc[18:49]  # Display the columns that were processed
# Out:
#                           filename  18  17  16  15  14  13  12  11  21  ...  \
# 18  440145_2024-10-08 LowerJawScan   0   0   0   0   0   0   0   0   0  ...
# 19  440145_2024-10-08 UpperJawScan   1   0   1   1   1   1   1   1   1  ...
# 20  443320_2024-07-16 LowerJawScan   0   0   0   0   0   0   0   0   0  ...
# 21  443320_2024-07-16 UpperJawScan   1   1   1   0   1   1   0   0   0  ...
# 22  461216_2024-10-22 UpperJawScan   0   0   0   1   1   1   1   1   1  ...
# 23  461714_2024-10-08 LowerJawScan   0   0   0   0   0   0   0   0   0  ...
# 24  461714_2024-10-08 UpperJawScan   0   1   1   1   1   1   1   1   1  ...
# 25  462781_2024-06-13 LowerJawScan   0   0   0   0   0   0   0   0   0  ...
# 26  462781_2024-06-13 UpperJawScan   1   1   1   1   1   1   1   1   1  ...
# 27  463530_2024-07-23 LowerJawScan   0   0   0   0   0   0   0   0   0  ...
# 28  464461_2024-09-17 LowerJawScan   0   0   0   0   0   0   0   0   0  ...
# 29  464461_2024-09-17 UpperJawScan   0   1   1   1   1   1   0   1   1  ...
# 30  464770_2024-04-19 LowerJawScan   0   0   0   0   0   0   0   0   0  ...
# 31  464770_2024-06-19 UpperJawScan   1   1   1   1   1   1   1   1   1  ...
# 32  465736_2024-09-22 UpperJawScan   0   0   1   0   0   1   1   1   1  ...
# 33  466953_2024-09-17 LowerJawScan   0   0   0   0   0   0   0   0   0  ...
# 34  466953_2024-10-22 UpperJawScan   0   1   1   1   1   1   1   1   1  ...
# 35  028231_2024-07-16 LowerJawScan   0   0   0   0   0   0   0   0   0  ...
# 36  028231_2024-07-16 UpperJawScan   0   0   1   1   1   1   1   1   1  ...
# 37  105587_2023-07-06 LowerJawScan   0   0   0   0   0   0   0   0   0  ...
# 38  105587_2023-07-06 UpperJawScan   0   1   1   1   1   1   1   1   1  ...
# 39  126217_2024-09-19 LowerJawScan   0   0   0   0   0   0   0   0   0  ...
# 40  126217_2024-09-19 UpperJawScan   0   0   1   1   1   1   1   1   1  ...
# 41  128680_2024-03-26 UpperJawScan   0   1   1   1   1   1   1   1   1  ...
# 42  130990_2024-06-14 LowerJawScan   0   0   0   0   0   0   0   0   0  ...
# 43  130990_2024-06-14 UpperJawScan   0   1   1   1   1   1   1   1   1  ...
# 44  163693_2023-06-23 LowerJawScan   0   0   0   0   0   0   0   0   0  ...
# 45  163693_2023-06-23 UpperJawScan   1   1   1   1   0   1   1   1   1  ...
# 46  171974_2024-11-28 LowerJawScan   0   0   0   0   0   0   0   0   0  ...
# 47  171974_2024-11-28 UpperJawScan   0   1   1   1   1   1   1   1   1  ...
# 48  185625_2023-08-28 LowerJawScan   0   0   0   0   0   0   0   0   0  ...
# 49  185625_2023-08-28 UpperJawScan   0   1   1   1   1   1   1   1   1  ...
#
#     41  42  43  44  45  46  47  48  Date of labeling  filetype
# 18   1   1   1   1   0   1   1   1        2024-11-05         0
# 19   0   0   0   0   0   0   0   0        2024-11-05         0
# 20   1   1   1   1   0   1   1   1        2024-11-05         0
# 21   0   0   0   0   0   0   0   0        2024-11-05         0
# 22   0   0   0   0   0   0   0   0        2024-11-05         0
# 23   1   1   1   1   1   1   1   0        2024-11-05         0
# 24   0   0   0   0   0   0   0   0        2024-11-05         0
# 25   1   1   1   1   1   1   1   1        2024-11-05         0
# 26   0   0   0   0   0   0   0   0        2024-11-05         0
# 27   1   1   1   1   1   1   1   1        2024-11-05         0
# 28   1   1   1   1   1   1   1   0        2024-11-05         0
# 29   0   0   0   0   0   0   0   0        2024-11-05         0
# 30   1   1   1   1   1   1   1   0        2024-11-05         0
# 31   0   0   0   0   0   0   0   0        2024-11-05         0
# 32   0   0   0   0   0   0   0   0        2024-11-05         0
# 33   1   1   1   1   1   1   1   0        2024-11-05         0
# 34   0   0   0   0   0   0   0   0        2024-11-05         0
# 35   1   1   1   1   0   1   1   0        2024-11-13         0
# 36   0   0   0   0   0   0   0   0        2024-11-13         0
# 37   1   1   1   1   1   1   1   1        2024-11-13         0
# 38   0   0   0   0   0   0   0   0        2024-11-13         0
# 39   1   1   1   1   1   1   1   0        2024-11-13         0
# 40   0   0   0   0   0   0   0   0        2024-11-13         0
# 41   0   0   0   0   0   0   0   0        2024-11-13         0
# 42   1   1   1   1   1   1   0   0        2024-11-13         0
# 43   0   0   0   0   0   0   0   0        2024-11-13         0
# 44   1   1   1   1   0   0   1   0        2024-11-13         0
# 45   0   0   0   0   0   0   0   0        2024-11-13         0
# 46   1   1   1   1   1   1   1   0        2024-11-13         0
# 47   0   0   0   0   0   0   0   0        2024-11-13         0
# 48   1   1   1   1   1   1   1   0        2024-11-13         0
# 49   0   0   0   0   0   0   0   0        2024-11-13         0
#
# [32 rows x 35 columns]

# %%
# import torch
# available_gpus = [3, 1]
# device = torch.device(f"cuda:{available_gpus[0]}" if torch.cuda.is_available() else "cpu")
 
# available_gpus

# %%
df.filename
# Out:
# 0      142595_2023-12-07 UpperJawScan
# 1      190250_2023-12-14 LowerJawScan
# 2      046375_2024-09-17 LowerJawScan
# 3      184824_2024-09-27 LowerJawScan
# 4      184824_2024-09-27 UpperJawScan
#                     ...
# 185    466662-2024-09-24 UpperJawScan
# 186    467830-2024-11-04 LowerJawScan
# 187    467830-2024-11-04 UpperJawScan
# 188         469239-01-14 LowerJawScan
# 189         469239-01-14 UpperJawScan
# Name: filename, Length: 190, dtype: object

# %%
import re

def extract_id(row):
    # extract digits at the start (before first _ or -)
    match = re.match(r"^(\d+)", row)
    if not match:
        return row  # fallback: return as-is if no match
    
    file_id = match.group(1)
    
    if "UpperJawScan" in row:
        return f"{file_id}_upper"
    elif "LowerJawScan" in row:
        return f"{file_id}_lower"
    else:
        return file_id

df["new_id"] = df["filename"].apply(extract_id)

# %%
df
# Out:
#                            filename  18  17  16  15  14  13  12  11  21  ...  \
# 0    142595_2023-12-07 UpperJawScan   0   1   1   0   1   1   1   1   1  ...
# 1    190250_2023-12-14 LowerJawScan   0   0   0   0   0   0   0   0   0  ...
# 2    046375_2024-09-17 LowerJawScan   0   0   0   0   0   0   0   0   0  ...
# 3    184824_2024-09-27 LowerJawScan   0   0   0   0   0   0   0   0   0  ...
# 4    184824_2024-09-27 UpperJawScan   0   0   1   1   1   1   1   1   1  ...
# ..                              ...  ..  ..  ..  ..  ..  ..  ..  ..  ..  ...
# 185  466662-2024-09-24 UpperJawScan   0   0   1   1   1   1   1   1   1  ...
# 186  467830-2024-11-04 LowerJawScan   0   0   0   0   0   0   0   0   0  ...
# 187  467830-2024-11-04 UpperJawScan   0   1   1   1   1   1   1   1   1  ...
# 188       469239-01-14 LowerJawScan   0   0   0   0   0   0   0   0   0  ...
# 189       469239-01-14 UpperJawScan   0   1   0   0   1   1   1   1   1  ...
#
#      42  43  44  45  46  47  48  Date of labeling  filetype        new_id
# 0     0   0   0   0   0   0   0        2024-10-21  only STL  142595_upper
# 1     1   1   1   0   1   0   0        2024-10-21  only STL  190250_lower
# 2     1   1   1   1   0   0   0        2024-11-05         0  046375_lower
# 3     1   1   1   1   1   0   0        2024-11-05         0  184824_lower
# 4     0   0   0   0   0   0   0        2024-11-05         0  184824_upper
# ..   ..  ..  ..  ..  ..  ..  ..               ...       ...           ...
# 185   0   0   0   0   0   0   0        2025-05-06         0  466662_upper
# 186   1   1   1   1   1   1   0        2025-05-06         0  467830_lower
# 187   0   0   0   0   0   0   0        2025-05-06         0  467830_upper
# 188   1   1   1   1   1   1   1        2025-05-06         0  469239_lower
# 189   0   0   0   0   0   0   0        2025-05-06         0  469239_upper
#
# [190 rows x 36 columns]

# %%
import os
import re

folder = "/home/user/tbrighton/blender_outputs/test_ply_views"

for fname in os.listdir(folder):
    if fname.endswith(".png"):
        old_path = os.path.join(folder, fname)

        # extract digits at the start (before first '_' or '-')
        match = re.match(r"^(\d+)", fname)
        if not match:
            continue  # skip if no id found
        file_id = match.group(1)

        # decide upper/lower based on filename
        lower_fname = fname.lower()
        if "upper" in lower_fname:
            new_name = f"{file_id}_upper.png"
        elif "lower" in lower_fname:
            new_name = f"{file_id}_lower.png"
        else:
            new_name = f"{file_id}.png"  # fallback if neither found

        new_path = os.path.join(folder, new_name)

        os.rename(old_path, new_path)
        print(f"Renamed: {fname} → {new_name}")
# Out:
# Renamed: 046375_lower.png → 046375_lower.png
# Renamed: 184824_lower.png → 184824_lower.png
# Renamed: 184824_upper.png → 184824_upper.png
# Renamed: 186908_lower.png → 186908_lower.png
# Renamed: 186908_upper.png → 186908_upper.png
# Renamed: 247695_lower.png → 247695_lower.png
# Renamed: 247869_upper.png → 247869_upper.png
# Renamed: 267942_upper.png → 267942_upper.png
# Renamed: 276774_lower.png → 276774_lower.png
# Renamed: 304802_upper.png → 304802_upper.png
# Renamed: 335735_lower.png → 335735_lower.png
# Renamed: 335735_upper.png → 335735_upper.png
# Renamed: 348449_lower.png → 348449_lower.png
# Renamed: 348449_upper.png → 348449_upper.png
# Renamed: 358702_lower.png → 358702_lower.png
# Renamed: 358702_upper.png → 358702_upper.png
# Renamed: 440145_lower.png → 440145_lower.png
# Renamed: 440145_upper.png → 440145_upper.png
# Renamed: 443320_lower.png → 443320_lower.png
# Renamed: 443320_upper.png → 443320_upper.png
# Renamed: 461216_upper.png → 461216_upper.png
# Renamed: 461714_lower.png → 461714_lower.png
# Renamed: 461714_upper.png → 461714_upper.png
# Renamed: 462781_lower.png → 462781_lower.png
# Renamed: 462781_upper.png → 462781_upper.png
# Renamed: 463530_lower.png → 463530_lower.png
# Renamed: 464461_lower.png → 464461_lower.png
# Renamed: 464461_upper.png → 464461_upper.png
# Renamed: 464770_lower.png → 464770_lower.png
# Renamed: 464770_upper.png → 464770_upper.png
# Renamed: 465736_upper.png → 465736_upper.png
# Renamed: 466953_lower.png → 466953_lower.png
# Renamed: 466953_upper.png → 466953_upper.png
# Renamed: 028231_lower.png → 028231_lower.png
# Renamed: 028231_upper.png → 028231_upper.png
# Renamed: 163693_lower.png → 163693_lower.png
# Renamed: 163693_upper.png → 163693_upper.png
# Renamed: 171974_lower.png → 171974_lower.png
# Renamed: 171974_upper.png → 171974_upper.png
# Renamed: 185625_lower.png → 185625_lower.png
# Renamed: 185625_upper.png → 185625_upper.png
# Renamed: 190007_upper.png → 190007_upper.png
# Renamed: 190250_lower.png → 190250_lower.png
# Renamed: 190250_upper.png → 190250_upper.png
# Renamed: 190841_lower.png → 190841_lower.png
# Renamed: 190841_upper.png → 190841_upper.png
# Renamed: 197152_lower.png → 197152_lower.png
# Renamed: 197152_upper.png → 197152_upper.png
# Renamed: 204632_lower.png → 204632_lower.png
# Renamed: 204632_upper.png → 204632_upper.png
# Renamed: 254549_lower.png → 254549_lower.png
# Renamed: 254549_upper.png → 254549_upper.png
# Renamed: 071214_lower.png → 071214_lower.png
# Renamed: 071214_upper.png → 071214_upper.png
# Renamed: 128217_lower.png → 128217_lower.png
# Renamed: 128217_upper.png → 128217_upper.png
# Renamed: 270465_lower.png → 270465_lower.png
# Renamed: 270465_upper.png → 270465_upper.png
# Renamed: 28231_lower.png → 28231_lower.png
# Renamed: 28231_upper.png → 28231_upper.png
# Renamed: 332139_upper.png → 332139_upper.png
# Renamed: 386054_lower.png → 386054_lower.png
# Renamed: 386054_upper.png → 386054_upper.png
# Renamed: 437032_lower.png → 437032_lower.png
# Renamed: 437032_upper.png → 437032_upper.png
# Renamed: 444401_lower.png → 444401_lower.png
# Renamed: 444401_upper.png → 444401_upper.png
# Renamed: 455222_lower.png → 455222_lower.png
# Renamed: 455222_upper.png → 455222_upper.png
# Renamed: 459106_lower.png → 459106_lower.png
# Renamed: 459106_upper.png → 459106_upper.png
# Renamed: 468394_lower.png → 468394_lower.png
# Renamed: 468394_upper.png → 468394_upper.png
# Renamed: 111044_lower.png → 111044_lower.png
# Renamed: 111044_upper.png → 111044_upper.png
# Renamed: 388864_lower.png → 388864_lower.png
# Renamed: 388864_upper.png → 388864_upper.png
# Renamed: 411125_lower.png → 411125_lower.png
# Renamed: 411125_upper.png → 411125_upper.png
# Renamed: 447773_upper.png → 447773_upper.png
# Renamed: 447773_lower.png → 447773_lower.png
# Renamed: 461999_lower.png → 461999_lower.png
# Renamed: 461999_upper.png → 461999_upper.png
# Renamed: 12345_lower.png → 12345_lower.png
# Renamed: 12345_upper.png → 12345_upper.png
# Renamed: 300572_lower.png → 300572_lower.png
# Renamed: 300572_upper.png → 300572_upper.png
# Renamed: 312388_lower.png → 312388_lower.png
# Renamed: 312388_upper.png → 312388_upper.png
# Renamed: 353457_lower.png → 353457_lower.png
# Renamed: 353457_upper.png → 353457_upper.png
# Renamed: 367898_lower.png → 367898_lower.png
# Renamed: 367898_upper.png → 367898_upper.png
# Renamed: 378939_lower.png → 378939_lower.png
# Renamed: 378939_upper.png → 378939_upper.png
# Renamed: 385120_lower.png → 385120_lower.png
# Renamed: 385120_upper.png → 385120_upper.png
# Renamed: 391123_lower.png → 391123_lower.png
# Renamed: 391123_upper.png → 391123_upper.png
# Renamed: 391232_lower.png → 391232_lower.png
# Renamed: 391232_upper.png → 391232_upper.png
# Renamed: 392711_lower.png → 392711_lower.png
# Renamed: 392711_upper.png → 392711_upper.png
# Renamed: 410054_lower.png → 410054_lower.png
# Renamed: 410054_upper.png → 410054_upper.png
# Renamed: 424453_upper.png → 424453_upper.png
# Renamed: 430050_lower.png → 430050_lower.png
# Renamed: 430050_upper.png → 430050_upper.png
# Renamed: 436779_lower.png → 436779_lower.png
# Renamed: 436779_upper.png → 436779_upper.png
# Renamed: 451820_lower.png → 451820_lower.png
# Renamed: 451820_upper.png → 451820_upper.png
# Renamed: 460194_upper.png → 460194_upper.png
# Renamed: 461094_lower.png → 461094_lower.png
# Renamed: 461094_upper.png → 461094_upper.png
# Renamed: 463452_lower.png → 463452_lower.png
# Renamed: 463452_upper.png → 463452_upper.png
# Renamed: 467845_lower.png → 467845_lower.png
# Renamed: 467845_upper.png → 467845_upper.png
# Renamed: 105587_lower.png → 105587_lower.png
# Renamed: 105587_upper.png → 105587_upper.png
# Renamed: 126217_lower.png → 126217_lower.png
# Renamed: 126217_upper.png → 126217_upper.png
# Renamed: 128680_lower.png → 128680_lower.png
# Renamed: 128680_upper.png → 128680_upper.png
# Renamed: 130990_lower.png → 130990_lower.png
# Renamed: 130990_upper.png → 130990_upper.png
# Renamed: 208018_lower.png → 208018_lower.png
# Renamed: 208018_upper.png → 208018_upper.png
# Renamed: 30629_lower.png → 30629_lower.png
# Renamed: 30629_upper.png → 30629_upper.png
# Renamed: 409239_lower.png → 409239_lower.png
# Renamed: 409239_upper.png → 409239_upper.png
# Renamed: 466488_lower.png → 466488_lower.png
# Renamed: 466488_upper.png → 466488_upper.png
# Renamed: 466662_lower.png → 466662_lower.png
# Renamed: 466662_upper.png → 466662_upper.png
# Renamed: 467830_lower.png → 467830_lower.png
# Renamed: 467830_upper.png → 467830_upper.png
# Renamed: 469239_lower.png → 469239_lower.png
# Renamed: 469239_upper.png → 469239_upper.png

# %%
import os

# get all .png names from folder (without extension)
folder = "/home/user/tbrighton/blender_outputs/test_ply_views"
png_names = [os.path.splitext(f)[0] for f in os.listdir(folder) if f.endswith(".png")]

# get new_id column from dataframe
df_names = df["new_id"].tolist()

# convert to sets for matching
set_png = set(png_names)
set_df = set(df_names)

# intersection = matching names
matches = set_df.intersection(set_png)

print(f"Total in df: {len(set_df)}")
print(f"Total in folder: {len(set_png)}")
print(f"Matching: {len(matches)}")

# if you want the actual matching names:
#print("Matching IDs:", matches)

# if you want the ones missing from either side:
missing_in_folder = set_df - set_png
missing_in_df = set_png - set_df
# Out:
# Total in df: 141
# Total in folder: 141
# Matching: 140

# %%
df.columns
# Out:
# Index([        'filename',                 18,                 17,
#                        16,                 15,                 14,
#                        13,                 12,                 11,
#                        21,                 22,                 23,
#                        24,                 25,                 26,
#                        27,                 28,               38.0,
#                        37,                 36,                 35,
#                        34,                 33,               32.0,
#                      31.0,                 41,                 42,
#                        43,                 44,                 45,
#                        46,                 47,                 48,
#        'Date of labeling',         'filetype',           'new_id'],
#       dtype='object')

# %%
df.to_csv("/home/user/tbrighton/blender-scripts/Testing/label1.csv", index=False)
print("\nSaved labeled test image data to label1.csv")
# Out:
# Saved labeled test image data to label1.csv

# %%
print(len(df))
# Out:
# 190

# %%
df.shape
# Out:
# (190, 36)
